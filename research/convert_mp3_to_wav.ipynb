# %%
# Convert mp3 to wav

# %%
## install modules

# %%
#!pip install pydub -qq
#!pip install tqdm -qq
#!pip install ipywidgets -qq

# %%
### apt-get install ffmpeg

# %%
## code

# %%
from os import path
from pydub import AudioSegment
import os
from tqdm import tqdm

# %%
data = {}
audio_dir = '../tatar_asr_3/'

# %%
for filename in os.listdir(audio_dir):
    name = os.path.splitext(filename)[0]
    if name not in data:
        data[name] = {
            'mp3': name + '.mp3',
            'wav': name + '.wav'
        }

# %%
for name in tqdm(data):
    sound = AudioSegment.from_mp3(audio_dir + data[name]['mp3'])
    sound.export(audio_dir + data[name]['wav'], format="wav")
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 19813/19813 [06:02<00:00, 54.60it/s]

# %%
import IPython
IPython.display.Audio(audio_dir + '106373_1521.wav')
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>
